# %% [markdown]
# # Machine Learning for Honey, Bee Colonies, and Almonds!
# ---
# ### We chose to perform a Linear Regression analysis on our datasets.
#  - Linear Regression can show the relationship between variables(independent and dependent) and allows for forecasting the future, given those trends.
#  - Linear Regression calculates a prediction value based on independent variables and is the most common form of machine learning.
# ---
# ### We will be looking at:
#  - Correlation Coefficient- a measure that determines the degree to which the movement of our two variables will be associated
#  - Mean Squared Error- the average squared difference between the estimated values and the actual value
#  - Coefficient of Determination (R^2)- how differences in one variable can be explained by a difference in the second variable
#  ---
#  #### This notebook incorporates elements from [Scikit Machine Learning Documentation](https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html), [Homemade Machine Learning Repository](https://github.com/trekhleb/homemade-machine-learning/blob/master/notebooks/linear_regression/multivariate_linear_regression_demo.ipynb), and [Sklearn Multiple Linear Regression](https://medium.com/@subarna.lamsal1/multiple-linear-regression-sklearn-and-statsmodels-798750747755).
#  ---
#  ### About Training and Testing:
#  - Training data is used for training of our linear model to form an accurate regressive analysis.
#  - Testing data will be used for validating our model.

# %% [markdown]
# ## First Study: Analysis of Honey Production Survey Data, in Dollars
# ---
# #### Question to Answer: `What is the Financial Future of Honey?`

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score


#Importing the data 
dataset = pd.read_csv('data\honey_survey_prod_dollars.csv')

X = dataset["Year"].values.reshape(-1,1)
y = dataset["Value"].values.reshape(-1,1)


# Split the data into training/testing sets
X_train = X[:-437]
X_test = X[-437:]

# Split the targets into training/testing sets
y_train = y[:-437]
y_test = y[-437:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train,y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
print('**********************')
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
print('**********************')
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination(R^2): %.2f'
      % r2_score(y_test, y_pred))
print('**********************')

# Plot outputs

plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='yellow', linewidth=3)


plt.xlabel("Year")
plt.ylabel("Honey Production ($100M)".format(y))
plt.title('Honey Production ($) Linear Regression Analysis')

plt.show()
plt.savefig('Honey_Production')
# Out:
# Coefficients:
#  [[262504.98997018]]
# **********************
# Mean squared error: 14775623184628.98
# **********************
# Coefficient of determination(R^2): -0.12
# **********************

# %% [markdown]
# ### Conclusions:
#  - Because there is a Coefficient, there IS a statisitcally significant relationship. The coefficient is positive, so the amount of honey produced is slowly increasing.
#  - The Coefficient of Determination is extremely close to zero. This means that there is little benefit no benefit is gained by doing regressive modeling on the values of Honey as they appear to have remained constant throughout the duration of the survey.
#  - The MSE is large, which means that that the data values are dispersed widely around the trend line.
#  - Answer to Question: `Honey Production is increasing but the growth has been slow.`

# %% [markdown]
# ## Second Study: Historical Survey Results for Bee Colonies
# ---
# #### Question to Answer: `What is the future outlook for Bee Colonies in the United States based on Year?`

# %%
#Importing the data 
dataset_2 = pd.read_csv('data/bee_colony_inventory_survey.csv')

X_2 = dataset_2["Year"].values.reshape(-1,1)
y_2 = dataset_2["Value"].values.reshape(-1,1)


# Split the data into training/testing sets
X_train_2 = X_2[:-437]
X_test_2 = X_2[-437:]

# Split the targets into training/testing sets
y_train_2 = y_2[:-437]
y_test_2 = y_2[-437:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train_2,y_train_2)

# Make predictions using the testing set
y_pred_2 = regr.predict(X_test_2)

# The coefficients
print('Coefficients: \n', regr.coef_)
print('**********************')
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test_2, y_pred_2))
print('**********************')
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination(R^2): %.2f'
      % r2_score(y_test_2, y_pred_2))
print('**********************')

# Plot outputs
plt.scatter(X_test_2, y_test_2,  color='black')
plt.plot(X_test_2, y_pred_2, color='yellow', linewidth=3)

plt.xlabel("Year")
plt.ylabel("Number of Colonies Surveyed")
plt.title('Bee Colony Linear Regression Analysis')

plt.xticks((1987,1988,1989,1990,1991,1992,1993,1994,1995,1996))
plt.yticks([10000,250000,500000,750000],['0','250,000','500,000','750,000','1,000,000'])

plt.show()
# Out:
# Coefficients:
#  [[212.1805977]]
# **********************
# Mean squared error: 8151205039.29
# **********************
# Coefficient of determination(R^2): -0.01
# **********************

# %% [markdown]
# ### Conclusions:
#  - Because there is a coefficient, there IS a statisitcally significant relationship. The coefficient is positive, so the amount of bee colonies is slowly increasing.
#  - The Coefficient of Determination is extremely close to zero. This means that there is little benefit no benefit is gained by doing regressive modeling on these colonies as they appear to have remained constant throughout the duration of the survey.
#  - The MSE is large, which means that that the data values are dispersed widely around the trend line.
#  - Answer to Question: `Bee Colonies are increasing slightly over time but the growth has been nearly constant.`

# %% [markdown]
# ## Third Study: Historical Survey Results for Acres Bearing Almonds
# ---
# #### Question to Answer: `What is the future outlook for Almond Production in the United States?`

# %%
#Importing the data 
dataset_3 = pd.read_csv('data/acres_bearing_almonds.csv')

X_3 = dataset_3["Year"].values.reshape(-1,1)
y_3 = dataset_3["Value_Acres"].values.reshape(-1,1)


# Split the data into training/testing sets
X_train = X_3[:-20]
X_test = X_3[-20:]

# Split the targets into training/testing sets
y_train = y_3[:-20]
y_test = y_3[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train,y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
print('**********************')
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
print('**********************')
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination(R^2): %.2f'
      % r2_score(y_test, y_pred))
print('**********************')

# Plot outputs
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='yellow', linewidth=3)

plt.xlabel("Year")
plt.ylabel("Acres Bearing Almonds")
plt.title('Almond Acres Linear Regression Analysis')


plt.xticks((2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017))
plt.yticks([0,250000,500000,750000,1000000],['0','250,000','500,000','750,000','1,000,000'])
#plt.yticklabels('10,000','250,000','500,000','750,000')
plt.show()
# Out:
# Coefficients:
#  [[7748.47130469]]
# **********************
# Mean squared error: 480582848166.76
# **********************
# Coefficient of determination(R^2): -43.76
# **********************

# %% [markdown]
# ### Conclusions:
#  - Because there is a Coefficient, there IS a statisitcally significant relationship. The coefficient is positive, so the amount acres bearing almonds is increasing.
#  - The Coefficient of Determination is very far from zero. This means that there is a benefit to doing regressive modeling on these acres as they appear to be increasing at a much faster pace than the other two regressive models.
#  - The MSE is large, which means that that the data values are dispersed widely around the trend line.
#  - Answer to Question: `Almond Production is increasing and and the growth has been faster, based on the slope of the trend line.`

# %%
## Final Study: Almond and Honey Production Based on Year, (Multivariate Analysis)
---
#### Question to Answer: `Is There More than one Explanatory Variable for the Regression Models? Can We Find a Link Between Honey and Almond Production?`

# %%
#import statsmodels as ssm
#import matplotlib.pyplot as plt
#from sklearn.preprocessing import linear_model 

#from sklearn.impute import SimpleImputer
#imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

#Processing my data for merge
#df_1 = dataset[["Year","Value"]].astype('int64').values.reshape(-1,1)
#df_2 = dataset_3[["Year","Value_Acres"]].astype('int64').values.reshape(-1,1)
#Merging my data
#all_data= pd.merge(dataset,dataset_3,on=["Year"],how='outer')
#clean_data= all_data.replace({'\n': ''}) 

#clean_data.head()
# Out:
#    Unnamed: 0_x Program_x  Year        Period_x Geo_Level_x     State_x  \
# 0         20147    SURVEY  2019  MARKETING YEAR       STATE     ALABAMA
# 1         20150    SURVEY  2019  MARKETING YEAR       STATE     ARIZONA
# 2         20153    SURVEY  2019  MARKETING YEAR       STATE    ARKANSAS
# 3         20156    SURVEY  2019  MARKETING YEAR       STATE  CALIFORNIA
# 4         20159    SURVEY  2019  MARKETING YEAR       STATE    COLORADO
#
#    County_x Commodity_x                        Data_Item_x Domain_x  ...  \
# 0       NaN       HONEY  HONEY - PRODUCTION, MEASURED IN $    TOTAL  ...
# 1       NaN       HONEY  HONEY - PRODUCTION, MEASURED IN $    TOTAL  ...
# 2       NaN       HONEY  HONEY - PRODUCTION, MEASURED IN $    TOTAL  ...
# 3       NaN       HONEY  HONEY - PRODUCTION, MEASURED IN $    TOTAL  ...
# 4       NaN       HONEY  HONEY - PRODUCTION, MEASURED IN $    TOTAL  ...
#
#   Period_y  Geo_Level_y  State_y  County_y Commodity_y Data_Item_y Domain_y  \
# 0      NaN          NaN      NaN       NaN         NaN         NaN      NaN
# 1      NaN          NaN      NaN       NaN         NaN         NaN      NaN
# 2      NaN          NaN      NaN       NaN         NaN         NaN      NaN
# 3      NaN          NaN      NaN       NaN         NaN         NaN      NaN
# 4      NaN          NaN      NaN       NaN         NaN         NaN      NaN
#
#   Domain Category_y Value_Acres CV_(%)_y
# 0               NaN         NaN      NaN
# 1               NaN         NaN      NaN
# 2               NaN         NaN      NaN
# 3               NaN         NaN      NaN
# 4               NaN         NaN      NaN
#
# [5 rows x 25 columns]

# %%
#X=clean_data[['Value','Value_Acres']].dropna()
#Y=clean_data['Year'].dropna()
#X = X.reshape(X.shape[1:])

# %%
#from sklearn.linear_model import LinearRegression
#reg=LinearRegression()     #initiating linearregression
#reg.fit(X,Y)

# %%
#X=ssm.add_constant(X)        
#to add constant value in the model
#model= ssm.OLS(Y,X).fit()         
#fitting the model
#predictions= model.summary()      
#summary of the model predictions
